# %% [markdown]
# <a href="https://colab.research.google.com/github/SOWJANYATILLAPUDI/FMML-COURSE-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 05:07:06--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   168MB/s    in 0.4s
#
# 2023-05-05 05:07:10 (168 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26218  1609.03279v2  This paper addresses the problem of face recog...    cs
# 6678   1705.02047v3  Predicting unobserved entries of a partially o...  stat
# 22400  1605.08301v2  We propose a data-driven, coarse-graining form...  stat
# 980     1410.0630v1  For discrete data, the likelihood $P(x)$ can b...  stat
# 13654  1502.00196v1  An electric vehicle (EV) may be used as energy...    cs
# ...             ...                                                ...   ...
# 31801   1005.2243v1  We derive generalization bounds for learning a...    cs
# 33734  1606.01552v1  The primate brain contains a hierarchy of visu...    cs
# 21911  1502.04416v5  We introduce and develop a novel approach to o...  stat
# 22853  1709.01233v5  Classifying samples into categories becomes in...  stat
# 22242  1510.00850v3  A latent space model for a family of random gr...  stat
#
#                                                    title  year  \
# 26218  Semi-Supervised Sparse Representation Based Cl...  2016
# 6678       Matrix Completion via Factorizing Polynomials  2017
# 22400                         Predictive Coarse-Graining  2016
# 980                Deep Directed Generative Autoencoders  2014
# 13654  Optimal V2G Scheduling of Electric Vehicles an...  2015
# ...                                                  ...   ...
# 31801                      Robustness and Generalization  2010
# 33734  View-tolerant face recognition and Hebbian lea...  2016
# 21911  Random Subspace Learning Approach to High-Dime...  2015
# 22853  Linear Optimal Low Rank Projection for High-Di...  2017
# 22242  Maximum Likelihood Latent Space Embedding of L...  2015
#
#                                                 keywords
# 26218  [addresses, recognition, recognize, typically,...
# 6678   [predicting, unobserved, partially, applicabil...
# 22400  [formulation, equilibrium, statistical, mechan...
# 980    [likelihood, rewritten, parametrized, probabil...
# 13654  [directional, electricity, electricity, schedu...
# ...                                                  ...
# 31801  [generalization, algorithms, robustness, diffe...
# 33734  [hierarchy, representations, relatively, prese...
# 21911  [introduce, detection, adaptation, dimension, ...
# 22853  [classifying, categories, intractable, princip...
# 22242  [probabilities, determined, positions, statist...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26218    [addresses, recognition, recognize, typically,...
# 6678     [predicting, unobserved, partially, applicabil...
# 22400    [formulation, equilibrium, statistical, mechan...
# 980      [likelihood, rewritten, parametrized, probabil...
# 13654    [directional, electricity, electricity, schedu...
#                                ...
# 16788    [framework, detecting, redundancy, supervised,...
# 13002    [considers, processes, differently, manifested...
# 31076    [excellent, surrogate, attention, intelligent,...
# 30467    [introduce, reconstruction, framework, convolu...
# 26395    [automatic, mechanized, recognition, processin...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8800 words.
# Out of those 4543 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="30a04b8f-85df-4b40-94a5-2499af49306d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30a04b8f-85df-4b40-94a5-2499af49306d")) {                    Plotly.newPlot(                        "30a04b8f-85df-4b40-94a5-2499af49306d",                        [{"x":["corrupted","representation","demonstrate","addresses","recognition","dictionaries","conditions","typically","different","expression","representing","unlabeled","supervised","variation","recognize","databases","experiments","represented","consisting","estimated","significantly","classification","prototype","insufficient","framework","characterize","variations","performance","variables","dictionary","recommender","optimization","probability","theoretical","predicting","applicability","transition","partially","efficient","redundant","unobserved","incorporating","computation","computational","developed","explicitly","information","factorization","observation","algorithm","especially","components","preserving","polynomials","recommendation","resulting","available","completion","guarantees","coordinate","computations","interactions","outperforms","embeddings","algorithms","factorizing","posterior","quantifying","discovery","inference","maximization","perspective","predictive","importantly","prominent","statistical","complexity","theoretic","furthermore","observables","improvement","probabilistic","comparative","presented","methodology","generators","corresponds","employing","revealing","parameters","hierarchical","solutions","selection","seamlessly","uncertainties","techniques","reflected","macroscopic","parallelizable","assessment","unavoidably","quantities","addressed","estimates","uncertainty","mechanics","expectation","prescribing","equilibrium","formulation","distributions","confidence","reconstructions","transforming","likelihood","ancestral","dimensions","rewritten","architecture","difficult","challenge","parametrized","reconstruction","propagation","autoencoder","gradually","factorizes","generating","deterministic","concentrates","parametric","regularizer","distribution","optimizing","objective","straightforward","estimator","generative","autoencoders","activations","characteristics","effectively","considers","instances","scheduling","electricity","commitment","directional","simulation","dimension","relationship","prediction","automatically","augmentation","symmetric","relations","nonparametric","flexibility","dynamically","relational","dimensionality","collected","illustrate","application","dimensional","coordinates","characterizing","financial","tractable","processes","continuous","movements","structure","described","environments","stochastic","epistemic","following","reinforcement","minimizes","sensitive","naturally","decomposition","usefulness","aleatoric","quantitatively","utilisation","implement","segmentation","methodologically","retrieval","construction","qualitatively","evaluated","contribution","presentons","designing","quantitative","perceptual","knowledge"],"y":[22,374,526,63,344,17,149,89,771,39,77,39,186,60,42,51,569,83,56,47,252,517,30,13,556,53,73,888,115,47,27,302,165,160,72,34,27,45,397,19,4,50,148,322,203,63,714,33,55,832,135,87,50,5,35,146,306,38,45,25,36,55,270,70,619,2,27,9,60,220,27,75,58,27,12,156,253,36,169,3,142,168,39,188,64,12,28,28,3,237,115,157,166,15,14,351,8,3,5,48,0,14,36,73,83,7,24,1,18,75,114,42,11,14,60,2,42,0,213,143,145,6,110,75,34,10,3,95,48,5,29,22,179,43,174,22,18,109,21,25,93,126,37,93,15,5,3,19,86,72,69,213,185,26,19,85,16,37,25,30,48,69,85,245,165,13,20,11,22,92,114,18,333,73,77,123,9,104,116,15,65,66,62,26,0,33,2,59,187,1,111,82,30,129,55,2,37,72,28,370],"type":"bar"},{"x":["corrupted","representation","demonstrate","addresses","recogni ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4543,), (4543, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>of</span> <span style=''>fuzzy</span> <span style=''>logic</span> <span style=''>to</span> <span style=''>Case</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.8083832335329342);'>Reasoning</span> <br/><br/><span style=''>The</span> <span style=''>article</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>discusses</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>fuzzy</span> <span style=''>logic</span> <span style=''>ideas</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>formalizing</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Case</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.8083832335329342);'>Reasoning</span> <span style=''>(CBR)</span> <span style=''>process</span> <span style=''>and</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.38181818181818183);'>measuring</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>CBR</span> <span style=''>systems</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>ABC</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computation</span> <span style=''>(ABC)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulation</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>(SVI)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appealing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inefficient</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>commonly</span> <span style=''>used</span> <span style=''>in</span> <span style=''>ABC</span> <span style=''>However</span> <span style=''>SVI</span> <span style=''>is</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>and</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exacerbated</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>We</span> <span style=''>draw</span> <span style=''>upon</span> <span style=''>recent</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>for</span> <span style=''>SV</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>low</span> <span style=''>variance</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>By</span> <span style=''>then</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploiting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>libraries</span> <span style=''>we</span> <span style=''>can</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Randomized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Loop</span> <span style=''>Cutset</span> <span style=''>Problem</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>weight</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>Finding</span> <span style=''>such</span> <span style=''>a</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>step</span> <span style=''>in</span> <span style=''>the</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioning</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>randomized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>finding</span> <span style=''>a</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>outputs</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>after</span> <span style=''>O(c</span> <span style=''>6k</span> <span style=''>kn)</span> <span style=''>steps</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>at</span> <span style=''>least</span> <span style=''>1</span> <span style=''>(1</span> <span style=''>1(6k))c6k</span> <span style=''>where</span> <span style=''>c</span> <span style=''>1</span> <span style=''>is</span> <span style=''>a</span> <span style=''>constant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>by</span> <span style=''>the</span> <span style=''>user</span> <span style=''>k</span> <span style=''>is</span> <span style=''>the</span> <span style=''>minimal</span> <span style=''>size</span> <span style=''>of</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>weight</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>and</span> <span style=''>n</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>vertices</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>that</span> <span style=''>a</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>often</span> <span style=''>finds</span> <span style=''>a</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>that</span> <span style=''>is</span> <span style=''>closer</span> <span style=''>to</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>weight</span> <span style=''>loop</span> <span style=''>cutset</span> <span style=''>than</span> <span style=''>the</span> <span style=''>ones</span> <span style=''>found</span> <span style=''>by</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>known</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>Active</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>with</span> <span style=''>Weak</span> <span style=''>Oracles</span> <br/><br/><span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>active</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>(SSAC)</span> <span style=''>utilizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>of</span> <span style=''>a</span> <span style=''>domain</span> <span style=''>expert</span> <span style=''>to</span> <span style=''>cluster</span> <span style=''>data</span> <span style=''>points</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactively</span> <span style=''>making</span> <span style=''>pairwise</span> <span style=''>same</span> <span style=''>cluster</span> <span style=''>queries</span> <span style=''>However</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>impractical</span> <span style=''>to</span> <span style=''>ask</span> <span style=''>human</span> <span style=''>oracles</span> <span style=''>to</span> <span style=''>answer</span> <span style=''>every</span> <span style=''>pairwise</span> <span style=''>query</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influence</span> <span style=''>of</span> <span style=''>allowing</span> <span style=''>not</span> <span style=''>sure</span> <span style=''>answers</span> <span style=''>from</span> <span style=''>a</span> <span style=''>weak</span> <span style=''>oracle</span> <span style=''>and</span> <span style=''>propose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>handle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainties</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Different</span> <span style=''>types</span> <span style=''>of</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>are</span> <span style=''>analyzed</span> <span style=''>to</span> <span style=''>cover</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>realistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>of</span> <span style=''>oracle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>abstraction</span> <span style=''>In</span> <span style=''>the</span> <span style=''>first</span> <span style=''>model</span> <span style=''>random</span> <span style=''>weak</span> <span style=''>oracle</span> <span style=''>an</span> <span style=''>oracle</span> <span style=''>randomly</span> <span style=''>abstains</span> <span style=''>with</span> <span style=''>a</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>We</span> <span style=''>also</span> <span style=''>proposed</span> <span style=''>two</span> <span style=''>distance</span> <span style=''>weak</span> <span style=''>oracle</span> <span style=''>models</span> <span style=''>which</span> <span style=''>simulate</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>getting</span> <span style=''>confused</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>between</span> <span style=''>two</span> <span style=''>points</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1334760885082084)
# 	reasoning (0.05389007851534618)
# 	segmentation (0.0667380442541042)
# 	experimental (0.13418986438258387)
# 	knowledge (0.13204853675945752)
# 	information (0.25481798715203424)
# 	detection (0.12919343326195576)
# 	recognition (0.12276945039257674)
# 	convolutional (0.12740899357601712)
# 	different (0.2751605995717345)
#
# Some Statistics words are:
# 	statistical (0.14914914914914915)
# 	stochastic (0.13763763763763764)
# 	theoretical (0.15115115115115116)
# 	variables (0.13863863863863865)
# 	algorithm (0.4029029029029029)
# 	estimation (0.17467467467467468)
# 	inference (0.1961961961961962)
# 	distribution (0.1946946946946947)
# 	regression (0.1856856856856857)
# 	dimensional (0.20270270270270271)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1de0af07-57f0-44f6-822e-13938979dde8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1de0af07-57f0-44f6-822e-13938979dde8")) {                    Plotly.newPlot(                        "1de0af07-57f0-44f6-822e-13938979dde8",                        [{"x":["corrupted","representation","demonstrate","addresses","recognition","dictionaries","conditions","typically","different","expression","representing","unlabeled","supervised","variation","recognize","databases","experiments","represented","consisting","estimated","significantly","classification","prototype","insufficient","framework","characterize","variations","performance","variables","dictionary","recommender","optimization","probability","theoretical","predicting","applicability","transition","partially","efficient","redundant","unobserved","incorporating","computation","computational","developed","explicitly","information","factorization","observation","algorithm","especially","components","preserving","polynomials","recommendation","resulting","available","completion","guarantees","coordinate","computations","interactions","outperforms","embeddings","algorithms","factorizing","posterior","quantifying","discovery","inference","maximization","perspective","predictive","importantly","prominent","statistical","complexity","theoretic","furthermore","observables","improvement","probabilistic","comparative","presented","methodology","generators","corresponds","employing","revealing","parameters","hierarchical","solutions","selection","seamlessly","uncertainties","techniques","reflected","macroscopic","parallelizable","assessment","unavoidably","quantities","addressed","estimates","uncertainty","mechanics","expectation","prescribing","equilibrium","formulation","distributions","confidence","reconstructions","transforming","likelihood","ancestral","dimensions","rewritten","architecture","difficult","challenge","parametrized","reconstruction","propagation","autoencoder","gradually","factorizes","generating","deterministic","concentrates","parametric","regularizer","distribution","optimizing","objective","straightforward","estimator","generative","autoencoders","activations","characteristics","effectively","considers","instances","scheduling","electricity","commitment","directional","simulation","dimension","relationship","prediction","automatically","augmentation","symmetric","relations","nonparametric","flexibility","dynamically","relational","dimensionality","collected","illustrate","application","dimensional","coordinates","characterizing","financial","tractable","processes","continuous","movements","structure","described","environments","stochastic","epistemic","following","reinforcement","minimizes","sensitive","naturally","decomposition","usefulness","aleatoric","quantitatively","utilisation","implement","segmentation","methodologically","retrieval","construction","qualitatively","evaluated","contribution","presentons","designing","quantitative","perceptual","knowledge","successfully","manipulation","additional","performing","identifying","functions","evaluation","demonstrations","representations","specification","considerable","discriminative","leveraging","necessarily","intermediate","deployment","installed","obstacles","unsupervised","imitation","abstraction","sequences","demonstration","engineering","exploration","qualitative","interesting","supplementary","embedding","analogous","corrected","adjacency","blockmodel","extensive","clustering","experiment","distinction","investigate","analysing","sentences","processing","containing","behaviours","categories","applications","linguistics","syntactical","performed","important","syntactic","intervention","automation","skeptical","relat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unavoidably
# 	rewritten
# 	aleatoric
# 	blockmodel
# 	backfitting
# 	conjugacy
# 	entropies
# 	exponents
# 	prognostic
# 	underpowered
# 	frequentist
# 	oscillations
# 	pessimistic
# 	allocating
# 	misspecification
# 	marginalize
# 	submanifold
# 	harvested
# 	subsample
# 	counterexample
# Some words which never appear in Statistics papers:
# 	utilisation
# 	presentons
# 	manipulation
# 	installed
# 	obstacles
# 	syntactical
# 	syntactic
# 	skeptical
# 	valuations
# 	argumentation
# 	persuasive
# 	disambiguate
# 	intrusions
# 	refutation
# 	contradiction
# 	propositional
# 	deblurring
# 	photometric
# 	landmarks
# 	animation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0709701194607376e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
